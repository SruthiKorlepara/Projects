# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("D:\Downloads\Titanic_dataset.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.drop(["Cabin","Ticket","Name","Fare"],axis=1,inplace=True)
print(data)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            892         0       3    male  34.5      0      0        Q
# 1            893         1       3  female  47.0      1      0        S
# 2            894         0       2    male  62.0      0      0        Q
# 3            895         0       3    male  27.0      0      0        S
# 4            896         1       3  female  22.0      1      1        S
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 413         1305         0       3    male   NaN      0      0        S
# 414         1306         1       1  female  39.0      0      0        C
# 415         1307         0       3    male  38.5      0      0        S
# 416         1308         0       3    male   NaN      0      0        S
# 417         1309         0       3    male   NaN      1      1        C
#
# [418 rows x 8 columns]

# %%
data["Age"].median()
# Out:
# 27.0

# %%
data["Age"]=data["Age"].fillna(value=27) # filling null values
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            892         0       3    male  34.5      0      0        Q
# 1            893         1       3  female  47.0      1      0        S
# 2            894         0       2    male  62.0      0      0        Q
# 3            895         0       3    male  27.0      0      0        S
# 4            896         1       3  female  22.0      1      1        S
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 413         1305         0       3    male  27.0      0      0        S
# 414         1306         1       1  female  39.0      0      0        C
# 415         1307         0       3    male  38.5      0      0        S
# 416         1308         0       3    male  27.0      0      0        S
# 417         1309         0       3    male  27.0      1      1        C
#
# [418 rows x 8 columns]

# %%
data.corr()
# Out:
# C:\Users\lenono\AppData\Local\Temp\ipykernel_2328\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch
# PassengerId     1.000000 -0.023245 -0.026751 -0.031447  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615  0.008035  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.467853  0.001087  0.018721
# Age            -0.031447  0.008035 -0.467853  1.000000 -0.071197 -0.043731
# SibSp           0.003818  0.099943  0.001087 -0.071197  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.043731  0.306895  1.000000

# %%
plt.hist(data["Embarked"], bins=15)
plt.xlabel("Sex")
plt.ylabel("Embarked")
plt.show()

# %%
sns.boxenplot(x=data["SibSp"], y=data["PassengerId"])

plt.xlabel("SibSp")
plt.ylabel("PassengerId")
plt.title("Passengers")
plt.show()

# %%
class_counts = data["Survived"].value_counts()
plt.pie(class_counts.values, labels=class_counts.index, autopct='%1.1f%%')
plt.title("survived and not survived")
plt.show()

# %%
sex_counts = data["Sex"].value_counts()
plt.bar(sex_counts.index, sex_counts.values,color="green")
plt.xlabel("Sex")
plt.xticks([0, 1])
plt.ylabel("Sibsp")
plt.title("Passenger counts by sex")
plt.show()

# %%
sns.countplot(x=data['Parch'],hue=data['Embarked'])
plt.show()

# %%
plt.boxplot(data["Age"])
plt.xlabel("Age")
plt.title("Ages of Passengers")
plt.show()

# %%
data["Embarked"].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
sns.heatmap(data.corr(), annot=True,fmt='.2%')
# Out:
# C:\Users\lenono\AppData\Local\Temp\ipykernel_2328\2310928751.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True,fmt='.2%')
# <Axes: >

# %%
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap="cool")
plt.title("Correlation matrix")
plt.show()
# Out:
# C:\Users\lenono\AppData\Local\Temp\ipykernel_2328\623608840.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
